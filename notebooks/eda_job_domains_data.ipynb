# %% [markdown]
# - Understanding the data to explore how the data is present in the dataset and if there is a need then we will perform data cleaning and add extra field for further analysis

# %%
import pandas as pd

# %%
df=pd.read_excel(r'C:\Users\dimpu\OneDrive\Desktop\Web_Scarping_project\data\web_scraped_data.xlsx')

# %% [markdown]
# df.head()

# %%
df.dtypes
# Out:
# Job Title             object
# Company Name          object
# Location              object
# Time Posted           object
# Experience Level      object
# Job Description       object
# Industry              object
# No of Applications     int64
# Domain                object
# dtype: object

# %% [markdown]
# - we have to remove the fields that we don't want for our analysis

# %%
df_new=df.drop(['Time Posted'],axis=1)

# %%
df_new
# Out:
#                                               Job Title  \
# 0                             Software Engineer (AI/ML)
# 1               Software Engineer - Applied AI Engineer
# 2               ML Inference Platform Intern (6 months)
# 3                                        AI ML Engineer
# 4                               AI/ML Engineer | Remote
# ...                                                 ...
# 5042                                   Product Designer
# 5043                                 Senior UX Designer
# 5044  Associate Creative Director - Visual and Motio...
# 5045                         Salesforce UI/UX Developer
# 5046                                    Angular JS Lead
#
#                   Company Name                     Location  Experience Level  \
# 0                Neilsoft Inc.     Pune, Maharashtra, India       Entry level
# 1                 Postman Corp  Bengaluru, Karnataka, India       Entry level
# 2                         aion  Bengaluru, Karnataka, India       Entry level
# 3     Gsource Technologies LLC     Pune, Maharashtra, India       Entry level
# 4                     Sofueled           Panaji, Goa, India       Entry level
# ...                        ...                          ...               ...
# 5042                    Uplers   Mumbai, Maharashtra, India  Mid-Senior level
# 5043    Dentsu Global Services     Pune, Maharashtra, India  Mid-Senior level
# 5044                      AKQA   Mumbai, Maharashtra, India  Mid-Senior level
# 5045       FPS Innovation Labs     Pune, Maharashtra, India  Mid-Senior level
# 5046        Persistent Systems     Pune, Maharashtra, India  Mid-Senior level
#
#                                         Job Description  \
# 0     Job Code: SES-0123-004Location: PunePosition: ...
# 1     Join Postman As An Applied AI EngineerAre you ...
# 2     About AIONAION is building the next generation...
# 3     About UsGsource Technologies helps companies a...
# 4     This is a remote position.Hey Hi..We're on the...
# ...                                                 ...
# 5042  Experience: 3 to 8 Years ExpSalary : Competiti...
# 5043  The purpose of this role is to be creative tas...
# 5044  As a Senior UI/UX Designer in the design team,...
# 5045  Career OpportunitiesThriving at FPSExplore Our...
# 5046  About PersistentWe are an AI-led, platform-dri...
#
#                                   Industry  No of Applications          Domain
# 0                          Design Services                  68  AI/ML Engineer
# 1                  Staffing and Recruiting                 168  AI/ML Engineer
# 2            IT Services and IT Consulting                  49  AI/ML Engineer
# 3                          Design Services                 200  AI/ML Engineer
# 4            IT Services and IT Consulting                 200  AI/ML Engineer
# ...                                    ...                 ...             ...
# 5042  Technology, Information and Internet                  31  UI/UX Designer
# 5043                  Advertising Services                 200  UI/UX Designer
# 5044                       Design Services                 104  UI/UX Designer
# 5045         IT Services and IT Consulting                  34  UI/UX Designer
# 5046         IT Services and IT Consulting                 200  UI/UX Designer
#
# [5047 rows x 8 columns]

# %% [markdown]
# - Removed Time Posted field from data frame

# %%
df_new.isna().sum()
# Out:
# Job Title             0
# Company Name          0
# Location              0
# Experience Level      0
# Job Description       0
# Industry              9
# No of Applications    0
# Domain                0
# dtype: int64

# %%
df_clean=df_new.dropna()

# %% [markdown]
# - Removed null values from data frame

# %%
df_clean.isna().sum()
# Out:
# Job Title             0
# Company Name          0
# Location              0
# Experience Level      0
# Job Description       0
# Industry              0
# No of Applications    0
# Domain                0
# dtype: int64

# %%
df_clean
# Out:
#                                               Job Title  \
# 0                             Software Engineer (AI/ML)
# 1               Software Engineer - Applied AI Engineer
# 2               ML Inference Platform Intern (6 months)
# 3                                        AI ML Engineer
# 4                               AI/ML Engineer | Remote
# ...                                                 ...
# 5042                                   Product Designer
# 5043                                 Senior UX Designer
# 5044  Associate Creative Director - Visual and Motio...
# 5045                         Salesforce UI/UX Developer
# 5046                                    Angular JS Lead
#
#                   Company Name                     Location  Experience Level  \
# 0                Neilsoft Inc.     Pune, Maharashtra, India       Entry level
# 1                 Postman Corp  Bengaluru, Karnataka, India       Entry level
# 2                         aion  Bengaluru, Karnataka, India       Entry level
# 3     Gsource Technologies LLC     Pune, Maharashtra, India       Entry level
# 4                     Sofueled           Panaji, Goa, India       Entry level
# ...                        ...                          ...               ...
# 5042                    Uplers   Mumbai, Maharashtra, India  Mid-Senior level
# 5043    Dentsu Global Services     Pune, Maharashtra, India  Mid-Senior level
# 5044                      AKQA   Mumbai, Maharashtra, India  Mid-Senior level
# 5045       FPS Innovation Labs     Pune, Maharashtra, India  Mid-Senior level
# 5046        Persistent Systems     Pune, Maharashtra, India  Mid-Senior level
#
#                                         Job Description  \
# 0     Job Code: SES-0123-004Location: PunePosition: ...
# 1     Join Postman As An Applied AI EngineerAre you ...
# 2     About AIONAION is building the next generation...
# 3     About UsGsource Technologies helps companies a...
# 4     This is a remote position.Hey Hi..We're on the...
# ...                                                 ...
# 5042  Experience: 3 to 8 Years ExpSalary : Competiti...
# 5043  The purpose of this role is to be creative tas...
# 5044  As a Senior UI/UX Designer in the design team,...
# 5045  Career OpportunitiesThriving at FPSExplore Our...
# 5046  About PersistentWe are an AI-led, platform-dri...
#
#                                   Industry  No of Applications          Domain
# 0                          Design Services                  68  AI/ML Engineer
# 1                  Staffing and Recruiting                 168  AI/ML Engineer
# 2            IT Services and IT Consulting                  49  AI/ML Engineer
# 3                          Design Services                 200  AI/ML Engineer
# 4            IT Services and IT Consulting                 200  AI/ML Engineer
# ...                                    ...                 ...             ...
# 5042  Technology, Information and Internet                  31  UI/UX Designer
# 5043                  Advertising Services                 200  UI/UX Designer
# 5044                       Design Services                 104  UI/UX Designer
# 5045         IT Services and IT Consulting                  34  UI/UX Designer
# 5046         IT Services and IT Consulting                 200  UI/UX Designer
#
# [5038 rows x 8 columns]

# %%
df_clean.duplicated().sum()
# Out:
# 236

# %%
df_final=df_clean.drop_duplicates()

# %% [markdown]
# - Removed duplicates from the data frmae

# %%
df_final.shape
# Out:
# (4802, 8)

# %%
import re
from typing import List

# ----------------------------------------------------------------------
# 1. Define Keyword Sets
# ----------------------------------------------------------------------

# Keywords indicating AI Creation, Management, or Advanced Use (Resilient/Growing Roles)
AI_ADOPTION_KEYWORDS: List[str] = [
    'machine learning', 'deep learning', 'generative ai', 'genai', 'llm', 'nlp', 
    'computer vision', 'neural networks', 'ai ethics', 'mlops', 'ai governance', 
    'tensorflow', 'pytorch', 'scikit-learn', 'hugging face', 'keras', 'aws sagemaker', 
    'azure ml', 'google ai platform', 'prompt engineering', 'data science', 
    'predictive modeling', 'algorithm development', 'feature engineering', 
    'big data architecture', 'statistical modeling', 'ai product manager', 
    'prompt engineer', 'ai/ml engineer', 'ai designer', 'ai specialist', 
    'chatGPT', 'gemini', 'RNN', 'rnn', 'CNN', 'cnn', 'Chatbot'
]

# Keywords indicating repetitive, rules-based tasks (Vulnerable/Changing Roles)
AUTOMATION_SUSCEPTIBILITY_KEYWORDS: List[str] = [
    'robotic process automation', 'rpa', 'uipath', 'blue prism', 'automation anywhere', 
    'process mapping','workflow automation', 'data entry', 
    'data cleaning', 'data manipulation', 'routine reporting', 'ticket resolution', 
    'l1/l2 support', 'standardized query', 'maintaining legacy systems', 
    'basic troubleshooting', 'compliance checklist', 'excel macro', 
    'standard documentation', 'status reporting', 'basic data gathering', 
    'invoice processing', 'expense reporting', 'automation'
]

def classify_job_description(description: str) -> str:
    """
    This funcyion will analyzes a single job description string and classifies its AI impact.
    """
    if pd.isna(description):
        return 'Missing Description'
    
    # Convert description to lower case for case-insensitive matching
    description_lower = str(description).lower()
    
    # Use regular expressions to count keyword occurrences
    def count_keywords(text: str, keywords: List[str]) -> int:
        count = 0
        # Create a single pattern for efficient searching (using word boundaries \b)
        pattern = r'\b(' + '|'.join(re.escape(k) for k in keywords) + r')\b'
        count = len(re.findall(pattern, text))
        return count

    # Count keywords
    adoption_count = count_keywords(description_lower, AI_ADOPTION_KEYWORDS)
    susceptibility_count = count_keywords(description_lower, AUTOMATION_SUSCEPTIBILITY_KEYWORDS)
    
    # Determine the classification based on the counts
    if susceptibility_count > adoption_count:
        return 'Automation Affected'
    elif adoption_count > susceptibility_count:
        return 'AI Adoption Affected'
    else:
        # Includes cases where both are zero or both are equal non-zero
        return 'Low AI Impact'

# %%
df_final.loc[:, 'AI_Impact_Category'] = df_final['Job Description'].apply(classify_job_description)

# %%
df_final
# Out:
#                                               Job Title  \
# 0                             Software Engineer (AI/ML)
# 1               Software Engineer - Applied AI Engineer
# 2               ML Inference Platform Intern (6 months)
# 3                                        AI ML Engineer
# 4                               AI/ML Engineer | Remote
# ...                                                 ...
# 5042                                   Product Designer
# 5043                                 Senior UX Designer
# 5044  Associate Creative Director - Visual and Motio...
# 5045                         Salesforce UI/UX Developer
# 5046                                    Angular JS Lead
#
#                   Company Name                     Location  Experience Level  \
# 0                Neilsoft Inc.     Pune, Maharashtra, India       Entry level
# 1                 Postman Corp  Bengaluru, Karnataka, India       Entry level
# 2                         aion  Bengaluru, Karnataka, India       Entry level
# 3     Gsource Technologies LLC     Pune, Maharashtra, India       Entry level
# 4                     Sofueled           Panaji, Goa, India       Entry level
# ...                        ...                          ...               ...
# 5042                    Uplers   Mumbai, Maharashtra, India  Mid-Senior level
# 5043    Dentsu Global Services     Pune, Maharashtra, India  Mid-Senior level
# 5044                      AKQA   Mumbai, Maharashtra, India  Mid-Senior level
# 5045       FPS Innovation Labs     Pune, Maharashtra, India  Mid-Senior level
# 5046        Persistent Systems     Pune, Maharashtra, India  Mid-Senior level
#
#                                         Job Description  \
# 0     Job Code: SES-0123-004Location: PunePosition: ...
# 1     Join Postman As An Applied AI EngineerAre you ...
# 2     About AIONAION is building the next generation...
# 3     About UsGsource Technologies helps companies a...
# 4     This is a remote position.Hey Hi..We're on the...
# ...                                                 ...
# 5042  Experience: 3 to 8 Years ExpSalary : Competiti...
# 5043  The purpose of this role is to be creative tas...
# 5044  As a Senior UI/UX Designer in the design team,...
# 5045  Career OpportunitiesThriving at FPSExplore Our...
# 5046  About PersistentWe are an AI-led, platform-dri...
#
#                                   Industry  No of Applications  \
# 0                          Design Services                  68
# 1                  Staffing and Recruiting                 168
# 2            IT Services and IT Consulting                  49
# 3                          Design Services                 200
# 4            IT Services and IT Consulting                 200
# ...                                    ...                 ...
# 5042  Technology, Information and Internet                  31
# 5043                  Advertising Services                 200
# 5044                       Design Services                 104
# 5045         IT Services and IT Consulting                  34
# 5046         IT Services and IT Consulting                 200
#
#               Domain    AI_Impact_Category
# 0     AI/ML Engineer  AI Adoption Affected
# 1     AI/ML Engineer  AI Adoption Affected
# 2     AI/ML Engineer  AI Adoption Affected
# 3     AI/ML Engineer  AI Adoption Affected
# 4     AI/ML Engineer  AI Adoption Affected
# ...              ...                   ...
# 5042  UI/UX Designer         Low AI Impact
# 5043  UI/UX Designer         Low AI Impact
# 5044  UI/UX Designer         Low AI Impact
# 5045  UI/UX Designer         Low AI Impact
# 5046  UI/UX Designer         Low AI Impact
#
# [4802 rows x 9 columns]

# %% [markdown]
# - As we created new column AI_Impact_Category with the help of Job Description, it is not required for further analysis

# %%
 df_Final=df_final.drop('Job Description',axis=1)

# %%
df_Final
# Out:
#                                               Job Title  \
# 0                             Software Engineer (AI/ML)
# 1               Software Engineer - Applied AI Engineer
# 2               ML Inference Platform Intern (6 months)
# 3                                        AI ML Engineer
# 4                               AI/ML Engineer | Remote
# ...                                                 ...
# 5042                                   Product Designer
# 5043                                 Senior UX Designer
# 5044  Associate Creative Director - Visual and Motio...
# 5045                         Salesforce UI/UX Developer
# 5046                                    Angular JS Lead
#
#                   Company Name                     Location  Experience Level  \
# 0                Neilsoft Inc.     Pune, Maharashtra, India       Entry level
# 1                 Postman Corp  Bengaluru, Karnataka, India       Entry level
# 2                         aion  Bengaluru, Karnataka, India       Entry level
# 3     Gsource Technologies LLC     Pune, Maharashtra, India       Entry level
# 4                     Sofueled           Panaji, Goa, India       Entry level
# ...                        ...                          ...               ...
# 5042                    Uplers   Mumbai, Maharashtra, India  Mid-Senior level
# 5043    Dentsu Global Services     Pune, Maharashtra, India  Mid-Senior level
# 5044                      AKQA   Mumbai, Maharashtra, India  Mid-Senior level
# 5045       FPS Innovation Labs     Pune, Maharashtra, India  Mid-Senior level
# 5046        Persistent Systems     Pune, Maharashtra, India  Mid-Senior level
#
#                                   Industry  No of Applications  \
# 0                          Design Services                  68
# 1                  Staffing and Recruiting                 168
# 2            IT Services and IT Consulting                  49
# 3                          Design Services                 200
# 4            IT Services and IT Consulting                 200
# ...                                    ...                 ...
# 5042  Technology, Information and Internet                  31
# 5043                  Advertising Services                 200
# 5044                       Design Services                 104
# 5045         IT Services and IT Consulting                  34
# 5046         IT Services and IT Consulting                 200
#
#               Domain    AI_Impact_Category
# 0     AI/ML Engineer  AI Adoption Affected
# 1     AI/ML Engineer  AI Adoption Affected
# 2     AI/ML Engineer  AI Adoption Affected
# 3     AI/ML Engineer  AI Adoption Affected
# 4     AI/ML Engineer  AI Adoption Affected
# ...              ...                   ...
# 5042  UI/UX Designer         Low AI Impact
# 5043  UI/UX Designer         Low AI Impact
# 5044  UI/UX Designer         Low AI Impact
# 5045  UI/UX Designer         Low AI Impact
# 5046  UI/UX Designer         Low AI Impact
#
# [4802 rows x 8 columns]

# %% [markdown]
# - Removed Job Description field from data frame

# %%
df_Final.to_csv('final_file_modified.csv',index=False)
